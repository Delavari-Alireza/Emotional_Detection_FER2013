# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
train_dir = "../train" #passing the path with training images
test_dir = "../test"   #passing the path with testing images

# %%
img_size = 48

# %%
train_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         #zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)



train_datagen = ImageDataGenerator(width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

# %%
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                                                         )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
X_train, y_train = next(train_generator)
X_test, y_test = next(validation_generator)

# %%
len(train_generator)
# Out:
# 359

# %%
X_train.shape
# Out:
# (64, 48, 48, 1)

# %%
y_train.shape
# Out:
# (64, 7)

# %%
X_test.shape
# Out:
# (64, 48, 48, 1)

# %%
y_test.shape
# Out:
# (64, 7)

# %%
class_names = train_generator.class_indices

class_names_swap = {v: k for k, v in class_names.items()}
print(class_names_swap)
# Out:
# {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}

# %%
import random
import cv2
import matplotlib.pyplot as plt
import numpy as np 

r = random.sample(range(X_train.shape[0]), 14)
for i in range(14):
    plt.subplot(2, 7, i+1)
    plt.imshow(X_train[r[i]],'gray')
    plt.title(class_names_swap[np.argmax(y_train[r[i]])])
    plt.axis("off")

# %%
from sklearn.utils import class_weight 
import numpy as np

class_weights = class_weight.compute_class_weight(
            class_weight = 'balanced',
            classes = np.unique(train_generator.classes), 
            y = train_generator.classes)

train_class_weights = dict(enumerate(class_weights))
# model.fit_generator(..., class_weight=train_class_weights)

# %%
train_class_weights
# Out:
# {0: 1.0266404434114071,
#  1: 9.401555464592715,
#  2: 1.0009587727708533,
#  3: 0.5684585684585685,
#  4: 0.826068191627104,
#  5: 0.8491570541259982,
#  6: 1.2933160650937552}

# %%
class_names_swap
# Out:
# {0: 'angry',
#  1: 'disgust',
#  2: 'fear',
#  3: 'happy',
#  4: 'neutral',
#  5: 'sad',
#  6: 'surprise'}

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def model_five(shape = (32, 32, 3), classes = 10):
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    
    x = identity_block(x, 64)
    x = identity_block(x, 64)
    x = identity_block(x, 64)
    x = convolutional_block(x, 128)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 128)
    x = identity_block(x, 128)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 128)
    x = identity_block(x, 128)
    x = identity_block(x, 128)
    x = convolutional_block(x, 256)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = convolutional_block(x, 512)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 512)
    
    x = tf.keras.layers.AveragePooling2D((2,2), padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(classes, activation = 'softmax')(x)
    model = tf.keras.models.Model(inputs = x_input, outputs = x, name = "model_two")
    return model

# %%
model = model_five(shape = (48, 48, 1), classes = 7)

epochs = 200
batch_size = 64
model.summary()
# Out:
# Model: "model_two"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 54, 54, 1)   0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 27, 27, 64)   3200        ['zero_padding2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 27, 27, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 27, 27, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 14, 14, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 14, 14, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 14, 14, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 14, 14, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 14, 14, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 14, 14, 64)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 128)    73856       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 7, 7, 128)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 128)    147584      ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 128)    8320        ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_8[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  activation_8 (Activation)      (None, 7, 7, 128)    0           ['add_3[0][0]']
#
#  dropout (Dropout)              (None, 7, 7, 128)    0           ['activation_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 128)    147584      ['dropout[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 7, 7, 128)    0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_10[0][0]',
#                                                                   'dropout[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 128)    0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 7, 7, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_12[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 7, 7, 128)    0           ['add_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 7, 7, 128)    0           ['activation_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 128)    147584      ['dropout_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 7, 7, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_14[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  activation_14 (Activation)     (None, 7, 7, 128)    0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 7, 7, 128)   512         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 128)   512         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_16[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_16 (Activation)     (None, 7, 7, 128)    0           ['add_7[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 7, 7, 128)   512         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 7, 7, 128)   512         ['conv2d_19[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_18[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 7, 7, 128)    0           ['add_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 4, 256)    295168      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 4, 4, 256)    33024       ['activation_18[0][0]']
#
#  add_9 (Add)                    (None, 4, 4, 256)    0           ['batch_normalization_20[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  activation_20 (Activation)     (None, 4, 4, 256)    0           ['add_9[0][0]']
#
#  dropout_2 (Dropout)            (None, 4, 4, 256)    0           ['activation_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 4, 4, 256)    590080      ['dropout_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_22[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  activation_22 (Activation)     (None, 4, 4, 256)    0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_24[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 4, 4, 256)    0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_26[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 4, 4, 256)    0           ['add_12[0][0]']
#
#  dropout_3 (Dropout)            (None, 4, 4, 256)    0           ['activation_26[0][0]']
#  conv2d_29 (Conv2D)             (None, 4, 4, 256)    590080      ['dropout_3[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_28[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  activation_28 (Activation)     (None, 4, 4, 256)    0           ['add_13[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_30[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 4, 4, 256)    0           ['add_14[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_32[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 4, 4, 256)    0           ['add_15[0][0]']
#
#  dropout_4 (Dropout)            (None, 4, 4, 256)    0           ['activation_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 4, 4, 256)    590080      ['dropout_4[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_34[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  activation_34 (Activation)     (None, 4, 4, 256)    0           ['add_16[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_38[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_36[0][0]',
#                                                                   'activation_34[0][0]']
#
#  activation_36 (Activation)     (None, 4, 4, 256)    0           ['add_17[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_38[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_38 (Activation)     (None, 4, 4, 256)    0           ['add_18[0][0]']
#
#  dropout_5 (Dropout)            (None, 4, 4, 256)    0           ['activation_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 4, 4, 256)    590080      ['dropout_5[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_42[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_40[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  activation_40 (Activation)     (None, 4, 4, 256)    0           ['add_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_44[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_42[0][0]',
#                                                                   'activation_40[0][0]']
#
#  activation_42 (Activation)     (None, 4, 4, 256)    0           ['add_20[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 2, 2, 512)    1180160     ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  conv2d_47 (Conv2D)             (None, 2, 2, 512)    131584      ['activation_42[0][0]']
#
#  add_21 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_44[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  activation_44 (Activation)     (None, 2, 2, 512)    0           ['add_21[0][0]']
#
#  dropout_6 (Dropout)            (None, 2, 2, 512)    0           ['activation_44[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 2, 2, 512)    2359808     ['dropout_6[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_48[0][0]']
#  ormalization)
#  activation_45 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_46[0][0]',
#                                                                   'dropout_6[0][0]']
#
#  activation_46 (Activation)     (None, 2, 2, 512)    0           ['add_22[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_51[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_48[0][0]',
#                                                                   'activation_46[0][0]']
#
#  activation_48 (Activation)     (None, 2, 2, 512)    0           ['add_23[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_53[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_50[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_50 (Activation)     (None, 2, 2, 512)    0           ['add_24[0][0]']
#
#  dropout_7 (Dropout)            (None, 2, 2, 512)    0           ['activation_50[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 512)    2359808     ['dropout_7[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_55[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_52[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  activation_52 (Activation)     (None, 2, 2, 512)    0           ['add_25[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_57[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_54[0][0]',
#                                                                   'activation_52[0][0]']
#
#  activation_54 (Activation)     (None, 2, 2, 512)    0           ['add_26[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_56[0][0]',
#                                                                   'activation_54[0][0]']
#
#  activation_56 (Activation)     (None, 2, 2, 512)    0           ['add_27[0][0]']
#
#  dropout_8 (Dropout)            (None, 2, 2, 512)    0           ['activation_56[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 2, 2, 512)    2359808     ['dropout_8[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_61[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_58[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  activation_58 (Activation)     (None, 2, 2, 512)    0           ['add_28[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['activation_58[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 512)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 512)          262656      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 7)            3591        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 52,870,791
# Trainable params: 52,838,151
# Non-trainable params: 32,640
# __________________________________________________________________________________________________

# %%
learning_rate = 0.001
decay_rate = learning_rate / 25
# momentum = 0.8
opt = Adam(lr=learning_rate,  decay=decay_rate)


model.compile(
    optimizer = opt, 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    'fer-43.h5', 
    monitor='val_accuracy', 
    verbose=1, 
    save_best_only=True, 
    save_weights_only=False,
    mode='auto'
)

# %%
import scipy.integrate

import scipy.special
import scipy

history = model.fit(x = train_generator,epochs = epochs,batch_size=batch_size,validation_data = validation_generator)
# Out:
# Epoch 1/200
# 359/359 [==============================] - 137s 347ms/step - loss: 2.0929 - accuracy: 0.2224 - val_loss: 1.8373 - val_accuracy: 0.1983
# Epoch 2/200
# 359/359 [==============================] - 113s 316ms/step - loss: 1.7542 - accuracy: 0.2800 - val_loss: 5.7908 - val_accuracy: 0.1453
# Epoch 3/200
# 359/359 [==============================] - 115s 321ms/step - loss: 1.6851 - accuracy: 0.3212 - val_loss: 1.8033 - val_accuracy: 0.2374
# Epoch 4/200
# 359/359 [==============================] - 116s 323ms/step - loss: 1.5770 - accuracy: 0.3745 - val_loss: 1.7107 - val_accuracy: 0.3289
# Epoch 5/200
# 359/359 [==============================] - 117s 326ms/step - loss: 1.5059 - accuracy: 0.3987 - val_loss: 1.5695 - val_accuracy: 0.3471
# Epoch 6/200
# 359/359 [==============================] - 118s 327ms/step - loss: 1.4571 - accuracy: 0.4227 - val_loss: 1.4916 - val_accuracy: 0.4092
# Epoch 7/200
# 359/359 [==============================] - 118s 328ms/step - loss: 1.4243 - accuracy: 0.4383 - val_loss: 1.4926 - val_accuracy: 0.4008
# Epoch 8/200
# 359/359 [==============================] - 118s 329ms/step - loss: 1.4003 - accuracy: 0.4549 - val_loss: 1.4063 - val_accuracy: 0.4351
# Epoch 9/200
# 359/359 [==============================] - 119s 331ms/step - loss: 1.3764 - accuracy: 0.4629 - val_loss: 1.4657 - val_accuracy: 0.4344
# Epoch 10/200
# 359/359 [==============================] - 119s 331ms/step - loss: 1.3600 - accuracy: 0.4687 - val_loss: 1.4732 - val_accuracy: 0.4365
# Epoch 11/200
# 359/359 [==============================] - 120s 333ms/step - loss: 1.3307 - accuracy: 0.4825 - val_loss: 1.4595 - val_accuracy: 0.4637
# Epoch 12/200
# 359/359 [==============================] - 119s 332ms/step - loss: 1.2952 - accuracy: 0.5002 - val_loss: 1.3379 - val_accuracy: 0.4923
# Epoch 13/200
# 359/359 [==============================] - 119s 331ms/step - loss: 1.2690 - accuracy: 0.5147 - val_loss: 1.5445 - val_accuracy: 0.3736
# Epoch 14/200
# 359/359 [==============================] - 119s 331ms/step - loss: 1.2495 - accuracy: 0.5227 - val_loss: 1.3956 - val_accuracy: 0.4658
# Epoch 15/200
# 359/359 [==============================] - 119s 331ms/step - loss: 1.2198 - accuracy: 0.5329 - val_loss: 1.3497 - val_accuracy: 0.4797
# Epoch 16/200
# 359/359 [==============================] - 118s 329ms/step - loss: 1.2070 - accuracy: 0.5381 - val_loss: 1.2515 - val_accuracy: 0.5189
# Epoch 17/200
# 359/359 [==============================] - 119s 332ms/step - loss: 1.2013 - accuracy: 0.5409 - val_loss: 1.2670 - val_accuracy: 0.5272
# Epoch 18/200
# 359/359 [==============================] - 120s 334ms/step - loss: 1.1726 - accuracy: 0.5551 - val_loss: 1.2409 - val_accuracy: 0.5370
# Epoch 19/200
# 359/359 [==============================] - 119s 331ms/step - loss: 1.1585 - accuracy: 0.5624 - val_loss: 1.2188 - val_accuracy: 0.5286
# Epoch 20/200
# 359/359 [==============================] - 118s 330ms/step - loss: 1.1493 - accuracy: 0.5715 - val_loss: 1.2761 - val_accuracy: 0.5182
# Epoch 21/200
# 359/359 [==============================] - 118s 330ms/step - loss: 1.1336 - accuracy: 0.5749 - val_loss: 1.3649 - val_accuracy: 0.4923
# Epoch 22/200
# 359/359 [==============================] - 118s 330ms/step - loss: 1.1212 - accuracy: 0.5806 - val_loss: 1.3046 - val_accuracy: 0.4986
# Epoch 23/200
# 359/359 [==============================] - 118s 329ms/step - loss: 1.0957 - accuracy: 0.5925 - val_loss: 1.2431 - val_accuracy: 0.5265
# Epoch 24/200
# 359/359 [==============================] - 120s 334ms/step - loss: 1.0977 - accuracy: 0.5901 - val_loss: 1.1769 - val_accuracy: 0.5482
# Epoch 25/200
# 359/359 [==============================] - 118s 330ms/step - loss: 1.0683 - accuracy: 0.6029 - val_loss: 1.1715 - val_accuracy: 0.5594
# Epoch 26/200
# 359/359 [==============================] - 118s 329ms/step - loss: 1.0575 - accuracy: 0.6058 - val_loss: 1.1886 - val_accuracy: 0.5349
# Epoch 27/200
# 359/359 [==============================] - 118s 328ms/step - loss: 1.0426 - accuracy: 0.6148 - val_loss: 1.3964 - val_accuracy: 0.4679
# Epoch 28/200
# 359/359 [==============================] - 119s 332ms/step - loss: 1.0260 - accuracy: 0.6203 - val_loss: 1.1474 - val_accuracy: 0.5649
# Epoch 29/200
# 359/359 [==============================] - 118s 330ms/step - loss: 1.0176 - accuracy: 0.6224 - val_loss: 1.1614 - val_accuracy: 0.5628
# Epoch 30/200
# 359/359 [==============================] - 118s 329ms/step - loss: 1.0027 - accuracy: 0.6250 - val_loss: 1.0686 - val_accuracy: 0.6082
# Epoch 31/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.9870 - accuracy: 0.6342 - val_loss: 1.0472 - val_accuracy: 0.6138
# Epoch 32/200
# 359/359 [==============================] - 122s 341ms/step - loss: 0.9771 - accuracy: 0.6392 - val_loss: 1.1441 - val_accuracy: 0.5705
# Epoch 33/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.9724 - accuracy: 0.6404 - val_loss: 1.1363 - val_accuracy: 0.5531
# Epoch 34/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.9554 - accuracy: 0.6451 - val_loss: 1.1190 - val_accuracy: 0.5803
# Epoch 35/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.9468 - accuracy: 0.6501 - val_loss: 1.1038 - val_accuracy: 0.5915
# Epoch 36/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.9378 - accuracy: 0.6515 - val_loss: 1.0734 - val_accuracy: 0.6006
# Epoch 37/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.9189 - accuracy: 0.6613 - val_loss: 1.0565 - val_accuracy: 0.6006
# Epoch 38/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.9107 - accuracy: 0.6654 - val_loss: 1.0458 - val_accuracy: 0.6110
# Epoch 39/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.9020 - accuracy: 0.6686 - val_loss: 1.0710 - val_accuracy: 0.6061
# Epoch 40/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.8962 - accuracy: 0.6677 - val_loss: 1.1918 - val_accuracy: 0.5810
# Epoch 41/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.8830 - accuracy: 0.6739 - val_loss: 1.0525 - val_accuracy: 0.6034
# Epoch 42/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.8671 - accuracy: 0.6846 - val_loss: 1.0669 - val_accuracy: 0.6082
# Epoch 43/200
# 359/359 [==============================] - 119s 333ms/step - loss: 0.8552 - accuracy: 0.6863 - val_loss: 1.0693 - val_accuracy: 0.6041
# Epoch 44/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.8574 - accuracy: 0.6838 - val_loss: 1.1592 - val_accuracy: 0.5754
# Epoch 45/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.8394 - accuracy: 0.6882 - val_loss: 1.0322 - val_accuracy: 0.6299
# Epoch 46/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.8327 - accuracy: 0.6944 - val_loss: 1.1187 - val_accuracy: 0.5852
# Epoch 47/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.8261 - accuracy: 0.6969 - val_loss: 1.0178 - val_accuracy: 0.6271
# Epoch 48/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.8166 - accuracy: 0.6994 - val_loss: 1.0071 - val_accuracy: 0.6299
# Epoch 49/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.8065 - accuracy: 0.7030 - val_loss: 1.0556 - val_accuracy: 0.6194
# Epoch 50/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.7949 - accuracy: 0.7071 - val_loss: 1.3098 - val_accuracy: 0.5286
# Epoch 51/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.7871 - accuracy: 0.7116 - val_loss: 1.0165 - val_accuracy: 0.6299
# Epoch 52/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.7803 - accuracy: 0.7140 - val_loss: 1.0060 - val_accuracy: 0.6487
# Epoch 53/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.7725 - accuracy: 0.7154 - val_loss: 0.9813 - val_accuracy: 0.6557
# Epoch 54/200
# 359/359 [==============================] - 121s 338ms/step - loss: 0.7579 - accuracy: 0.7218 - val_loss: 1.0702 - val_accuracy: 0.6194
# Epoch 55/200
# 359/359 [==============================] - 122s 341ms/step - loss: 0.7577 - accuracy: 0.7219 - val_loss: 1.0260 - val_accuracy: 0.6327
# Epoch 56/200
# 359/359 [==============================] - 121s 336ms/step - loss: 0.7421 - accuracy: 0.7299 - val_loss: 1.0174 - val_accuracy: 0.6383
# Epoch 57/200
# 359/359 [==============================] - 122s 340ms/step - loss: 0.7418 - accuracy: 0.7308 - val_loss: 1.0343 - val_accuracy: 0.6278
# Epoch 58/200
# 359/359 [==============================] - 122s 338ms/step - loss: 0.7324 - accuracy: 0.7339 - val_loss: 1.0167 - val_accuracy: 0.6278
# Epoch 59/200
# 359/359 [==============================] - 121s 337ms/step - loss: 0.7222 - accuracy: 0.7355 - val_loss: 1.0187 - val_accuracy: 0.6459
# Epoch 60/200
# 359/359 [==============================] - 121s 336ms/step - loss: 0.7119 - accuracy: 0.7433 - val_loss: 1.0317 - val_accuracy: 0.6515
# Epoch 61/200
# 359/359 [==============================] - 121s 337ms/step - loss: 0.7091 - accuracy: 0.7413 - val_loss: 1.0039 - val_accuracy: 0.6459
# Epoch 62/200
# 359/359 [==============================] - 126s 352ms/step - loss: 0.7050 - accuracy: 0.7443 - val_loss: 1.0162 - val_accuracy: 0.6376
# Epoch 63/200
# 359/359 [==============================] - 130s 362ms/step - loss: 0.6908 - accuracy: 0.7467 - val_loss: 1.0602 - val_accuracy: 0.6187
# Epoch 64/200
# 359/359 [==============================] - 121s 336ms/step - loss: 0.6834 - accuracy: 0.7493 - val_loss: 1.0471 - val_accuracy: 0.6215
# Epoch 65/200
# 359/359 [==============================] - 121s 337ms/step - loss: 0.6738 - accuracy: 0.7543 - val_loss: 1.0986 - val_accuracy: 0.6054
# Epoch 66/200
# 359/359 [==============================] - 121s 336ms/step - loss: 0.6639 - accuracy: 0.7565 - val_loss: 1.0665 - val_accuracy: 0.6320
# Epoch 67/200
# 359/359 [==============================] - 122s 339ms/step - loss: 0.6620 - accuracy: 0.7603 - val_loss: 1.1656 - val_accuracy: 0.6075
# Epoch 68/200
# 359/359 [==============================] - 120s 335ms/step - loss: 0.6584 - accuracy: 0.7594 - val_loss: 1.0133 - val_accuracy: 0.6390
# Epoch 69/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.6459 - accuracy: 0.7644 - val_loss: 1.0136 - val_accuracy: 0.6508
# Epoch 70/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.6430 - accuracy: 0.7697 - val_loss: 1.0285 - val_accuracy: 0.6292
# Epoch 71/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.6313 - accuracy: 0.7718 - val_loss: 1.0568 - val_accuracy: 0.6397
# Epoch 72/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.6258 - accuracy: 0.7706 - val_loss: 1.0842 - val_accuracy: 0.6117
# Epoch 73/200
# 359/359 [==============================] - 120s 335ms/step - loss: 0.6205 - accuracy: 0.7766 - val_loss: 1.0713 - val_accuracy: 0.6292
# Epoch 74/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.6104 - accuracy: 0.7801 - val_loss: 1.0303 - val_accuracy: 0.6446
# Epoch 75/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.6102 - accuracy: 0.7799 - val_loss: 1.0522 - val_accuracy: 0.6480
# Epoch 76/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.5993 - accuracy: 0.7838 - val_loss: 1.0762 - val_accuracy: 0.6411
# Epoch 77/200
# 359/359 [==============================] - 119s 333ms/step - loss: 0.5940 - accuracy: 0.7859 - val_loss: 1.0422 - val_accuracy: 0.6453
# Epoch 78/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.5893 - accuracy: 0.7882 - val_loss: 1.0566 - val_accuracy: 0.6459
# Epoch 79/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.5760 - accuracy: 0.7915 - val_loss: 1.0525 - val_accuracy: 0.6425
# Epoch 80/200
# 359/359 [==============================] - 121s 336ms/step - loss: 0.5834 - accuracy: 0.7881 - val_loss: 1.0289 - val_accuracy: 0.6578
# Epoch 81/200
# 359/359 [==============================] - 120s 335ms/step - loss: 0.5682 - accuracy: 0.7928 - val_loss: 1.0833 - val_accuracy: 0.6550
# Epoch 82/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.5691 - accuracy: 0.7930 - val_loss: 1.0724 - val_accuracy: 0.6243
# Epoch 83/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.5645 - accuracy: 0.7953 - val_loss: 1.0578 - val_accuracy: 0.6390
# Epoch 84/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5562 - accuracy: 0.7971 - val_loss: 1.0298 - val_accuracy: 0.6459
# Epoch 85/200
# 359/359 [==============================] - 120s 335ms/step - loss: 0.5505 - accuracy: 0.8022 - val_loss: 1.0597 - val_accuracy: 0.6439
# Epoch 86/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5439 - accuracy: 0.8017 - val_loss: 1.0828 - val_accuracy: 0.6501
# Epoch 87/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5355 - accuracy: 0.8075 - val_loss: 1.1114 - val_accuracy: 0.6194
# Epoch 88/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5280 - accuracy: 0.8094 - val_loss: 1.0709 - val_accuracy: 0.6369
# Epoch 89/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.5250 - accuracy: 0.8090 - val_loss: 1.0877 - val_accuracy: 0.6571
# Epoch 90/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5279 - accuracy: 0.8101 - val_loss: 1.0807 - val_accuracy: 0.6432
# Epoch 91/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5139 - accuracy: 0.8156 - val_loss: 1.1649 - val_accuracy: 0.6194
# Epoch 92/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5098 - accuracy: 0.8188 - val_loss: 1.0824 - val_accuracy: 0.6397
# Epoch 93/200
# 359/359 [==============================] - 124s 345ms/step - loss: 0.5024 - accuracy: 0.8198 - val_loss: 1.0781 - val_accuracy: 0.6655
# Epoch 94/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.5050 - accuracy: 0.8160 - val_loss: 1.1674 - val_accuracy: 0.6180
# Epoch 95/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.4970 - accuracy: 0.8196 - val_loss: 1.0828 - val_accuracy: 0.6557
# Epoch 96/200
# 359/359 [==============================] - 119s 333ms/step - loss: 0.4983 - accuracy: 0.8195 - val_loss: 1.1248 - val_accuracy: 0.6529
# Epoch 97/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.4828 - accuracy: 0.8245 - val_loss: 1.1240 - val_accuracy: 0.6173
# Epoch 98/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4885 - accuracy: 0.8248 - val_loss: 1.0937 - val_accuracy: 0.6453
# Epoch 99/200
# 359/359 [==============================] - 120s 335ms/step - loss: 0.4685 - accuracy: 0.8327 - val_loss: 1.2028 - val_accuracy: 0.5901
# Epoch 100/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.4756 - accuracy: 0.8287 - val_loss: 1.0711 - val_accuracy: 0.6508
# Epoch 101/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.4680 - accuracy: 0.8347 - val_loss: 1.0947 - val_accuracy: 0.6446
# Epoch 102/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.4580 - accuracy: 0.8340 - val_loss: 1.1387 - val_accuracy: 0.6404
# Epoch 103/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4635 - accuracy: 0.8305 - val_loss: 1.0667 - val_accuracy: 0.6585
# Epoch 104/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4533 - accuracy: 0.8374 - val_loss: 1.1496 - val_accuracy: 0.6313
# Epoch 105/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.4593 - accuracy: 0.8325 - val_loss: 1.0711 - val_accuracy: 0.6620
# Epoch 106/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4406 - accuracy: 0.8419 - val_loss: 1.0951 - val_accuracy: 0.6634
# Epoch 107/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4446 - accuracy: 0.8398 - val_loss: 1.0766 - val_accuracy: 0.6613
# Epoch 108/200
# 359/359 [==============================] - 119s 333ms/step - loss: 0.4439 - accuracy: 0.8427 - val_loss: 1.1001 - val_accuracy: 0.6613
# Epoch 109/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.4256 - accuracy: 0.8483 - val_loss: 1.1435 - val_accuracy: 0.6355
# Epoch 110/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4305 - accuracy: 0.8459 - val_loss: 1.1153 - val_accuracy: 0.6515
# Epoch 111/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4306 - accuracy: 0.8449 - val_loss: 1.1641 - val_accuracy: 0.6571
# Epoch 112/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.4255 - accuracy: 0.8465 - val_loss: 1.0874 - val_accuracy: 0.6655
# Epoch 113/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.4245 - accuracy: 0.8476 - val_loss: 1.0891 - val_accuracy: 0.6543
# Epoch 114/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.4135 - accuracy: 0.8532 - val_loss: 1.1369 - val_accuracy: 0.6480
# Epoch 115/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.4071 - accuracy: 0.8548 - val_loss: 1.1216 - val_accuracy: 0.6634
# Epoch 116/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4112 - accuracy: 0.8507 - val_loss: 1.1959 - val_accuracy: 0.6355
# Epoch 117/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4053 - accuracy: 0.8551 - val_loss: 1.1006 - val_accuracy: 0.6599
# Epoch 118/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.4018 - accuracy: 0.8569 - val_loss: 1.1487 - val_accuracy: 0.6662
# Epoch 119/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.4043 - accuracy: 0.8515 - val_loss: 1.1056 - val_accuracy: 0.6557
# Epoch 120/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.3920 - accuracy: 0.8603 - val_loss: 1.1547 - val_accuracy: 0.6397
# Epoch 121/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3889 - accuracy: 0.8592 - val_loss: 1.1753 - val_accuracy: 0.6564
# Epoch 122/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3830 - accuracy: 0.8641 - val_loss: 1.1300 - val_accuracy: 0.6529
# Epoch 123/200
# 359/359 [==============================] - 123s 341ms/step - loss: 0.3868 - accuracy: 0.8637 - val_loss: 1.1471 - val_accuracy: 0.6508
# Epoch 124/200
# 359/359 [==============================] - 125s 349ms/step - loss: 0.3776 - accuracy: 0.8628 - val_loss: 1.1726 - val_accuracy: 0.6313
# Epoch 125/200
# 359/359 [==============================] - 119s 333ms/step - loss: 0.3751 - accuracy: 0.8672 - val_loss: 1.1456 - val_accuracy: 0.6662
# Epoch 126/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.3718 - accuracy: 0.8644 - val_loss: 1.1890 - val_accuracy: 0.6599
# Epoch 127/200
# 359/359 [==============================] - 120s 334ms/step - loss: 0.3710 - accuracy: 0.8665 - val_loss: 1.1741 - val_accuracy: 0.6508
# Epoch 128/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3590 - accuracy: 0.8699 - val_loss: 1.3332 - val_accuracy: 0.6229
# Epoch 129/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3653 - accuracy: 0.8691 - val_loss: 1.1717 - val_accuracy: 0.6480
# Epoch 130/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3601 - accuracy: 0.8711 - val_loss: 1.1393 - val_accuracy: 0.6620
# Epoch 131/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.3541 - accuracy: 0.8736 - val_loss: 1.2200 - val_accuracy: 0.6508
# Epoch 132/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.3564 - accuracy: 0.8726 - val_loss: 1.2945 - val_accuracy: 0.6355
# Epoch 133/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.3634 - accuracy: 0.8690 - val_loss: 1.1523 - val_accuracy: 0.6655
# Epoch 134/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.3420 - accuracy: 0.8770 - val_loss: 1.1676 - val_accuracy: 0.6529
# Epoch 135/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.3456 - accuracy: 0.8757 - val_loss: 1.2156 - val_accuracy: 0.6571
# Epoch 136/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.3358 - accuracy: 0.8782 - val_loss: 1.2103 - val_accuracy: 0.6543
# Epoch 137/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.3406 - accuracy: 0.8784 - val_loss: 1.2433 - val_accuracy: 0.6439
# Epoch 138/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.3350 - accuracy: 0.8803 - val_loss: 1.2507 - val_accuracy: 0.6508
# Epoch 139/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.3332 - accuracy: 0.8797 - val_loss: 1.2002 - val_accuracy: 0.6480
# Epoch 140/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.3376 - accuracy: 0.8804 - val_loss: 1.2176 - val_accuracy: 0.6383
# Epoch 141/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.3240 - accuracy: 0.8834 - val_loss: 1.2278 - val_accuracy: 0.6543
# Epoch 142/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.3307 - accuracy: 0.8831 - val_loss: 1.2579 - val_accuracy: 0.6536
# Epoch 143/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3222 - accuracy: 0.8834 - val_loss: 1.2644 - val_accuracy: 0.6453
# Epoch 144/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3211 - accuracy: 0.8864 - val_loss: 1.2987 - val_accuracy: 0.6327
# Epoch 145/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.3190 - accuracy: 0.8855 - val_loss: 1.2932 - val_accuracy: 0.6334
# Epoch 146/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3183 - accuracy: 0.8859 - val_loss: 1.3062 - val_accuracy: 0.6397
# Epoch 147/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.3109 - accuracy: 0.8891 - val_loss: 1.3121 - val_accuracy: 0.6341
# Epoch 148/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3122 - accuracy: 0.8887 - val_loss: 1.2924 - val_accuracy: 0.6390
# Epoch 149/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3093 - accuracy: 0.8909 - val_loss: 1.2382 - val_accuracy: 0.6432
# Epoch 150/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.3088 - accuracy: 0.8907 - val_loss: 1.2403 - val_accuracy: 0.6536
# Epoch 151/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2999 - accuracy: 0.8927 - val_loss: 1.1991 - val_accuracy: 0.6781
# Epoch 152/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.3013 - accuracy: 0.8931 - val_loss: 1.2098 - val_accuracy: 0.6634
# Epoch 153/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.3012 - accuracy: 0.8925 - val_loss: 1.1982 - val_accuracy: 0.6599
# Epoch 154/200
# 359/359 [==============================] - 121s 338ms/step - loss: 0.2925 - accuracy: 0.8957 - val_loss: 1.2163 - val_accuracy: 0.6550
# Epoch 155/200
# 359/359 [==============================] - 120s 333ms/step - loss: 0.2933 - accuracy: 0.8968 - val_loss: 1.2573 - val_accuracy: 0.6487
# Epoch 156/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2942 - accuracy: 0.8955 - val_loss: 1.2351 - val_accuracy: 0.6522
# Epoch 157/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2819 - accuracy: 0.8998 - val_loss: 1.2663 - val_accuracy: 0.6550
# Epoch 158/200
# 359/359 [==============================] - 119s 332ms/step - loss: 0.2817 - accuracy: 0.9009 - val_loss: 1.2267 - val_accuracy: 0.6466
# Epoch 159/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2848 - accuracy: 0.8980 - val_loss: 1.2455 - val_accuracy: 0.6515
# Epoch 160/200
# 359/359 [==============================] - 118s 330ms/step - loss: 0.2862 - accuracy: 0.8964 - val_loss: 1.2270 - val_accuracy: 0.6529
# Epoch 161/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2807 - accuracy: 0.9021 - val_loss: 1.2671 - val_accuracy: 0.6487
# Epoch 162/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.2808 - accuracy: 0.8981 - val_loss: 1.2433 - val_accuracy: 0.6529
# Epoch 163/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2742 - accuracy: 0.9023 - val_loss: 1.2981 - val_accuracy: 0.6494
# Epoch 164/200
# 359/359 [==============================] - 119s 330ms/step - loss: 0.2706 - accuracy: 0.9048 - val_loss: 1.3090 - val_accuracy: 0.6487
# Epoch 165/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.2780 - accuracy: 0.8991 - val_loss: 1.2915 - val_accuracy: 0.6466
# Epoch 166/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2639 - accuracy: 0.9043 - val_loss: 1.2963 - val_accuracy: 0.6592
# Epoch 167/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2695 - accuracy: 0.9047 - val_loss: 1.2733 - val_accuracy: 0.6620
# Epoch 168/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2645 - accuracy: 0.9060 - val_loss: 1.2647 - val_accuracy: 0.6620
# Epoch 169/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2682 - accuracy: 0.9046 - val_loss: 1.3102 - val_accuracy: 0.6564
# Epoch 170/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2600 - accuracy: 0.9070 - val_loss: 1.2956 - val_accuracy: 0.6494
# Epoch 171/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2559 - accuracy: 0.9095 - val_loss: 1.3547 - val_accuracy: 0.6585
# Epoch 172/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2498 - accuracy: 0.9111 - val_loss: 1.3515 - val_accuracy: 0.6571
# Epoch 173/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2505 - accuracy: 0.9105 - val_loss: 1.3177 - val_accuracy: 0.6571
# Epoch 174/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2507 - accuracy: 0.9107 - val_loss: 1.3030 - val_accuracy: 0.6613
# Epoch 175/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2521 - accuracy: 0.9104 - val_loss: 1.2841 - val_accuracy: 0.6662
# Epoch 176/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2454 - accuracy: 0.9114 - val_loss: 1.3340 - val_accuracy: 0.6494
# Epoch 177/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2447 - accuracy: 0.9105 - val_loss: 1.3228 - val_accuracy: 0.6557
# Epoch 178/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2473 - accuracy: 0.9112 - val_loss: 1.3422 - val_accuracy: 0.6418
# Epoch 179/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2391 - accuracy: 0.9130 - val_loss: 1.3879 - val_accuracy: 0.6564
# Epoch 180/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2381 - accuracy: 0.9145 - val_loss: 1.3215 - val_accuracy: 0.6557
# Epoch 181/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2415 - accuracy: 0.9132 - val_loss: 1.3273 - val_accuracy: 0.6557
# Epoch 182/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2464 - accuracy: 0.9131 - val_loss: 1.3322 - val_accuracy: 0.6459
# Epoch 183/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2320 - accuracy: 0.9177 - val_loss: 1.3223 - val_accuracy: 0.6669
# Epoch 184/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2371 - accuracy: 0.9146 - val_loss: 1.2989 - val_accuracy: 0.6662
# Epoch 185/200
# 359/359 [==============================] - 119s 331ms/step - loss: 0.2390 - accuracy: 0.9168 - val_loss: 1.3401 - val_accuracy: 0.6557
# Epoch 186/200
# 359/359 [==============================] - 123s 341ms/step - loss: 0.2306 - accuracy: 0.9172 - val_loss: 1.3722 - val_accuracy: 0.6634
# Epoch 187/200
# 359/359 [==============================] - 119s 329ms/step - loss: 0.2288 - accuracy: 0.9201 - val_loss: 1.3508 - val_accuracy: 0.6599
# Epoch 188/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2258 - accuracy: 0.9188 - val_loss: 1.3633 - val_accuracy: 0.6578
# Epoch 189/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2304 - accuracy: 0.9175 - val_loss: 1.3210 - val_accuracy: 0.6543
# Epoch 190/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2286 - accuracy: 0.9188 - val_loss: 1.2685 - val_accuracy: 0.6753
# Epoch 191/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2245 - accuracy: 0.9198 - val_loss: 1.3272 - val_accuracy: 0.6557
# Epoch 192/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2282 - accuracy: 0.9185 - val_loss: 1.3352 - val_accuracy: 0.6648
# Epoch 193/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2266 - accuracy: 0.9183 - val_loss: 1.3432 - val_accuracy: 0.6585
# Epoch 194/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2144 - accuracy: 0.9243 - val_loss: 1.3241 - val_accuracy: 0.6599
# Epoch 195/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2217 - accuracy: 0.9206 - val_loss: 1.3141 - val_accuracy: 0.6669
# Epoch 196/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2258 - accuracy: 0.9185 - val_loss: 1.3047 - val_accuracy: 0.6529
# Epoch 197/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2077 - accuracy: 0.9250 - val_loss: 1.3656 - val_accuracy: 0.6550
# Epoch 198/200
# 359/359 [==============================] - 118s 328ms/step - loss: 0.2134 - accuracy: 0.9227 - val_loss: 1.3103 - val_accuracy: 0.6669
# Epoch 199/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2153 - accuracy: 0.9248 - val_loss: 1.3113 - val_accuracy: 0.6648
# Epoch 200/200
# 359/359 [==============================] - 118s 329ms/step - loss: 0.2090 - accuracy: 0.9252 - val_loss: 1.3424 - val_accuracy: 0.6550

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('deeperdropout442_200_model.h5')
model.save_weights('deeperdropout442_200_weights.h5')

# %%
train_loss, train_acc = model.evaluate(train_generator)
test_loss, test_acc   = model.evaluate(validation_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 359/359 [==============================] - 48s 133ms/step - loss: 0.2284 - accuracy: 0.9203
# 23/23 [==============================] - 6s 240ms/step - loss: 1.3424 - accuracy: 0.6550
# final train accuracy = 92.03 , validation accuracy = 65.50

# %%
y_pred = model.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
class_labels = validation_generator.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(validation_generator.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 23/23 [==============================] - 6s 86ms/step
# Confusion Matrix
# [[31  1 35 40 25 36 23]
#  [ 2  0  2  4  2  8  4]
#  [35  0 19 56 30 45 19]
#  [50  3 50 78 60 75 38]
#  [35  3 38 58 34 47 31]
#  [38  0 36 55 36 56 28]
#  [19  3 27 39 24 35 19]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.15      0.16      0.15       191
#      disgust       0.00      0.00      0.00        22
#         fear       0.09      0.09      0.09       204
#        happy       0.24      0.22      0.23       354
#      neutral       0.16      0.14      0.15       246
#          sad       0.19      0.22      0.20       249
#     surprise       0.12      0.11      0.12       166
#
#     accuracy                           0.17      1432
#    macro avg       0.13      0.14      0.13      1432
# weighted avg       0.16      0.17      0.16      1432

# %%
y_pred = model.predict(train_generator)
y_pred = np.argmax(y_pred, axis=1)
class_labels = train_generator.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(train_generator.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(train_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 359/359 [==============================] - 29s 81ms/step
# Confusion Matrix
# [[ 450   47  470  754  556  563  356]
#  [  67    3   47   87   51   56   38]
#  [ 433   43  516  829  518  593  346]
#  [ 787   78  851 1423 1001 1028  604]
#  [ 569   45  558 1025  646  684  445]
#  [ 491   59  571  980  649  691  423]
#  [ 365   39  380  682  370  451  250]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14      3196
#      disgust       0.01      0.01      0.01       349
#         fear       0.15      0.16      0.15      3278
#        happy       0.25      0.25      0.25      5772
#      neutral       0.17      0.16      0.17      3972
#          sad       0.17      0.18      0.17      3864
#     surprise       0.10      0.10      0.10      2537
#
#     accuracy                           0.17     22968
#    macro avg       0.14      0.14      0.14     22968
# weighted avg       0.17      0.17      0.17     22968
