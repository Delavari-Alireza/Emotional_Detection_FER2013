# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
train_dir = "../train" #passing the path with training images
test_dir = "../test"   #passing the path with testing images

# %%
img_size = 48

# %%
train_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         #zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

# %%
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                                                         )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
X_train, y_train = next(train_generator)
X_test, y_test = next(validation_generator)

# %%
len(train_generator)
# Out:
# 359

# %%
X_train.shape
# Out:
# (64, 48, 48, 1)

# %%
y_train.shape
# Out:
# (64, 7)

# %%
X_test.shape
# Out:
# (64, 48, 48, 1)

# %%
y_test.shape
# Out:
# (64, 7)

# %%
class_names = train_generator.class_indices

class_names_swap = {v: k for k, v in class_names.items()}
print(class_names_swap)
# Out:
# {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}

# %%
import random
import cv2
import matplotlib.pyplot as plt
import numpy as np 

r = random.sample(range(X_train.shape[0]), 14)
for i in range(14):
    plt.subplot(2, 7, i+1)
    plt.imshow(X_train[r[i]],'gray')
    plt.title(class_names_swap[np.argmax(y_train[r[i]])])
    plt.axis("off")

# %%
from sklearn.utils import class_weight 
import numpy as np

class_weights = class_weight.compute_class_weight(
            class_weight = 'balanced',
            classes = np.unique(train_generator.classes), 
            y = train_generator.classes)

train_class_weights = dict(enumerate(class_weights))
# model.fit_generator(..., class_weight=train_class_weights)

# %%
train_class_weights
# Out:
# {0: 1.0266404434114071,
#  1: 9.401555464592715,
#  2: 1.0009587727708533,
#  3: 0.5684585684585685,
#  4: 0.826068191627104,
#  5: 0.8491570541259982,
#  6: 1.2933160650937552}

# %%
class_names_swap
# Out:
# {0: 'angry',
#  1: 'disgust',
#  2: 'fear',
#  3: 'happy',
#  4: 'neutral',
#  5: 'sad',
#  6: 'surprise'}

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def model_th(shape = (32, 32, 3), classes = 10):
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    
    x = identity_block(x, 64)
    x = identity_block(x, 64)
    x = identity_block(x, 64)
    x = convolutional_block(x, 128)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 128)
    x = identity_block(x, 128)
    x = identity_block(x, 128)
    x = convolutional_block(x, 256)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = convolutional_block(x, 512)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)
    x = tf.keras.layers.Dropout( 0.25)(x)
    x = identity_block(x, 512)
    
    x = tf.keras.layers.AveragePooling2D((2,2), padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(256, activation = 'relu')(x)
    x = tf.keras.layers.Dense(classes, activation = 'softmax')(x)
    model = tf.keras.models.Model(inputs = x_input, outputs = x, name = "model_two")
    return model

# %%
model = model_th(shape = (48, 48, 1), classes = 7)

epochs = 100
batch_size = 64
model.summary()
# Out:
# Model: "model_two"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 54, 54, 1)   0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 27, 27, 64)   3200        ['zero_padding2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 27, 27, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 27, 27, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 14, 14, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 14, 14, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 14, 14, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 14, 14, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 14, 14, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 14, 14, 64)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 128)    73856       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 7, 7, 128)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 128)    147584      ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 128)    8320        ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_8[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  activation_8 (Activation)      (None, 7, 7, 128)    0           ['add_3[0][0]']
#
#  dropout (Dropout)              (None, 7, 7, 128)    0           ['activation_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 128)    147584      ['dropout[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 7, 7, 128)    0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_10[0][0]',
#                                                                   'dropout[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 128)    0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 7, 7, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_12[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 7, 7, 128)    0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 7, 7, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_14[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 7, 7, 128)    0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 4, 4, 256)    295168      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 4, 4, 256)    33024       ['activation_14[0][0]']
#
#  add_7 (Add)                    (None, 4, 4, 256)    0           ['batch_normalization_16[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  activation_16 (Activation)     (None, 4, 4, 256)    0           ['add_7[0][0]']
#
#  dropout_1 (Dropout)            (None, 4, 4, 256)    0           ['activation_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 4, 256)    590080      ['dropout_1[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 4, 4, 256)    0           ['batch_normalization_18[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  activation_18 (Activation)     (None, 4, 4, 256)    0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 4, 4, 256)    0           ['batch_normalization_20[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 4, 4, 256)    0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_22[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 4, 4, 256)    0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_24[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 4, 4, 256)    0           ['add_11[0][0]']
#
#  dropout_2 (Dropout)            (None, 4, 4, 256)    0           ['activation_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 4, 4, 256)    590080      ['dropout_2[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_26[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  activation_26 (Activation)     (None, 4, 4, 256)    0           ['add_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_26[0][0]']
#  batch_normalization_27 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_28[0][0]',
#                                                                   'activation_26[0][0]']
#
#  activation_28 (Activation)     (None, 4, 4, 256)    0           ['add_13[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_30[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 4, 4, 256)    0           ['add_14[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 2, 2, 512)    1180160     ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 2, 2, 512)    131584      ['activation_30[0][0]']
#
#  add_15 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_32[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  activation_32 (Activation)     (None, 2, 2, 512)    0           ['add_15[0][0]']
#
#  dropout_3 (Dropout)            (None, 2, 2, 512)    0           ['activation_32[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 2, 2, 512)    2359808     ['dropout_3[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_37[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_34[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  activation_34 (Activation)     (None, 2, 2, 512)    0           ['add_16[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_39[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_36[0][0]',
#                                                                   'activation_34[0][0]']
#
#  activation_36 (Activation)     (None, 2, 2, 512)    0           ['add_17[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_41[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_38[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_38 (Activation)     (None, 2, 2, 512)    0           ['add_18[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_39[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_43[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_40[0][0]',
#                                                                   'activation_38[0][0]']
#
#  activation_40 (Activation)     (None, 2, 2, 512)    0           ['add_19[0][0]']
#
#  dropout_4 (Dropout)            (None, 2, 2, 512)    0           ['activation_40[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 2, 2, 512)    2359808     ['dropout_4[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_45[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_42[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  activation_42 (Activation)     (None, 2, 2, 512)    0           ['add_20[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['activation_42[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 512)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 512)          262656      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 7)            1799        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 38,231,687
# Trainable params: 38,208,263
# Non-trainable params: 23,424
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer = 'adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )

# %%
import scipy.integrate

import scipy.special
import scipy

history = model.fit(x = train_generator,epochs = epochs,batch_size=batch_size,validation_data = validation_generator, class_weight=train_class_weights)
# Out:
# Epoch 1/100
# 359/359 [==============================] - 285s 756ms/step - loss: 2.0299 - accuracy: 0.1580 - val_loss: 1.9769 - val_accuracy: 0.1250
# Epoch 2/100
# 359/359 [==============================] - 82s 229ms/step - loss: 1.8828 - accuracy: 0.2006 - val_loss: 2.0225 - val_accuracy: 0.1725
# Epoch 3/100
# 359/359 [==============================] - 85s 236ms/step - loss: 1.8248 - accuracy: 0.2604 - val_loss: 1.8660 - val_accuracy: 0.2430
# Epoch 4/100
# 359/359 [==============================] - 86s 239ms/step - loss: 1.7877 - accuracy: 0.2384 - val_loss: 1.9751 - val_accuracy: 0.2577
# Epoch 5/100
# 359/359 [==============================] - 86s 240ms/step - loss: 1.7779 - accuracy: 0.2286 - val_loss: 1.8123 - val_accuracy: 0.1439
# Epoch 6/100
# 359/359 [==============================] - 93s 260ms/step - loss: 1.7454 - accuracy: 0.2410 - val_loss: 1.8073 - val_accuracy: 0.2451
# Epoch 7/100
# 359/359 [==============================] - 94s 262ms/step - loss: 1.7432 - accuracy: 0.2706 - val_loss: 2.0035 - val_accuracy: 0.2011
# Epoch 8/100
# 359/359 [==============================] - 92s 257ms/step - loss: 1.7278 - accuracy: 0.2489 - val_loss: 1.7446 - val_accuracy: 0.2535
# Epoch 9/100
# 359/359 [==============================] - 92s 257ms/step - loss: 1.7011 - accuracy: 0.3039 - val_loss: 2.2961 - val_accuracy: 0.1774
# Epoch 10/100
# 359/359 [==============================] - 92s 257ms/step - loss: 1.6613 - accuracy: 0.3450 - val_loss: 1.6085 - val_accuracy: 0.4078
# Epoch 11/100
# 359/359 [==============================] - 93s 258ms/step - loss: 1.6203 - accuracy: 0.3584 - val_loss: 1.5902 - val_accuracy: 0.3771
# Epoch 12/100
# 359/359 [==============================] - 93s 258ms/step - loss: 1.5933 - accuracy: 0.3796 - val_loss: 1.5703 - val_accuracy: 0.3813
# Epoch 13/100
# 359/359 [==============================] - 92s 257ms/step - loss: 1.5604 - accuracy: 0.3975 - val_loss: 1.6117 - val_accuracy: 0.3883
# Epoch 14/100
# 359/359 [==============================] - 93s 258ms/step - loss: 1.5320 - accuracy: 0.4074 - val_loss: 1.4936 - val_accuracy: 0.4309
# Epoch 15/100
# 359/359 [==============================] - 92s 257ms/step - loss: 1.4995 - accuracy: 0.4151 - val_loss: 1.5276 - val_accuracy: 0.4246
# Epoch 16/100
# 359/359 [==============================] - 92s 258ms/step - loss: 1.4930 - accuracy: 0.4099 - val_loss: 1.4735 - val_accuracy: 0.4623
# Epoch 17/100
# 359/359 [==============================] - 92s 257ms/step - loss: 1
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('dropout33_100_model.h5')
model.save_weights('dropout33_100_weights.h5')

# %%
train_loss, train_acc = model.evaluate(train_generator)
test_loss, test_acc   = model.evaluate(validation_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 359/359 [==============================] - 23s 63ms/step - loss: 0.9668 - accuracy: 0.6397
# 23/23 [==============================] - 2s 64ms/step - loss: 1.1114 - accuracy: 0.5936
# final train accuracy = 63.97 , validation accuracy = 59.36

# %%
y_pred = model.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
class_labels = validation_generator.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(validation_generator.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 23/23 [==============================] - 3s 71ms/step
# Confusion Matrix
# [[22  0 38 48 25 35 23]
#  [ 3  0  3  4  4  6  2]
#  [28  1 45 31 25 50 24]
#  [57  6 63 69 47 71 41]
#  [22  5 47 56 36 46 34]
#  [35  6 46 45 45 46 26]
#  [24  2 29 37 29 28 17]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.12      0.12      0.12       191
#      disgust       0.00      0.00      0.00        22
#         fear       0.17      0.22      0.19       204
#        happy       0.24      0.19      0.21       354
#      neutral       0.17      0.15      0.16       246
#          sad       0.16      0.18      0.17       249
#     surprise       0.10      0.10      0.10       166
#
#     accuracy                           0.16      1432
#    macro avg       0.14      0.14      0.14      1432
# weighted avg       0.17      0.16      0.16      1432

# %%
y_pred = model.predict(train_generator)
y_pred = np.argmax(y_pred, axis=1)
class_labels = train_generator.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(train_generator.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(train_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 359/359 [==============================] - 22s 60ms/step
# Confusion Matrix
# [[ 423   47  561  699  413  668  385]
#  [  43    3   58   86   52   60   47]
#  [ 437   56  542  706  460  685  392]
#  [ 774   88 1028 1198  756 1238  690]
#  [ 526   78  695  832  523  805  513]
#  [ 496   71  656  855  527  798  461]
#  [ 318   56  460  537  337  526  303]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.13      0.14      3196
#      disgust       0.01      0.01      0.01       349
#         fear       0.14      0.17      0.15      3278
#        happy       0.24      0.21      0.22      5772
#      neutral       0.17      0.13      0.15      3972
#          sad       0.17      0.21      0.18      3864
#     surprise       0.11      0.12      0.11      2537
#
#     accuracy                           0.17     22968
#    macro avg       0.14      0.14      0.14     22968
# weighted avg       0.17      0.17      0.17     22968
